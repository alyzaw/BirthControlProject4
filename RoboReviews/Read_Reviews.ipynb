# %%
# !pip install textgenrnn
# Out:
# ...
#   Stored in directory: C:\Users\Alyza\AppData\Local\pip\Cache\wheels\23\46\b0\4444949d8310e43e273e931cfa9e175c34b7a2349c8114a6f7
# Successfully built textgenrnn
# ...

# %%
from textgenrnn import textgenrnn
t = textgenrnn()
t.train_from_file('input.txt', num_epochs=3)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Alyza\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 6,209 texts collected.
# Training on 3,282,955 character sequences.
# WARNING:tensorflow:From C:\Users\Alyza\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\Alyza\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/3
# ...
