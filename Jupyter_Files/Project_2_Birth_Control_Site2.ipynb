# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd
import time
import re
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
Base = declarative_base()
import pymysql
pymysql.install_as_MySQLdb()
import numpy as np

# Set path 
import sys
sys.path.append('../')

# Config variables
from config import remote_db_endpoint, remote_db_port
from config import remote_gwsis_dbname, remote_gwsis_dbuser, remote_gwsis_dbpwd
from config import local_gwsis_dbname, local_gwsis_dbuser, local_gwsis_dbpwd

# %% [markdown]
# Create local and remote engines and pass in MySQL connection

# %%
# AWS Database Connection
engine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_endpoint}:{remote_db_port}/{remote_gwsis_dbname}")

# %%
# Create a remote database engine connection
conn = engine.connect()

# %%
# Use Splinter to initiate browser
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#['depo-provera','mirena','nuvaring','ortho-tri-cyclen','norethindrone','nexplanon','xulane','paragard']
types_list = ['medroxyprogesterone/depo-provera-','levonorgestrel/mirena-','ethinyl-estradiol-etonogestrel/nuvaring-',
              'ethinyl-estradiol-norgestimate/','ethinyl-estradiol-norethindrone/','etonogestrel/nexplanon-',
              'ethinyl-estradiol-norelgestromin/xulane-','copper-topical/']

# %% [markdown]
# Scrape all the reiviews from [Drugs.com](https://www.drugs.com/) for each of the birth control types. This may take several minutes!

# %%
bc_type = []
review_text = []
stars = []
publish_date = []

for t in types_list:
    # URL of page to be scraped (last scraped 3/30/2019)
    url = f'https://www.drugs.com/comments/{t}for-contraception.html'
    browser.visit(url)
    
    # Limit it to 13 pages or reviews for each or else it will take forever
    for x in range(1, 13):

        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')

        # Retrieve the parent divs for all reviews
        results = soup.find_all('div', class_='user-comment')

        # Loop through results to retrieve review details
        for result in results:
            body = result.span.text
            bc = t 
            try:
                #edited tags on 3/30 to reflect website updates
                date = result.find('p', class_="text-size-smaller user-name user-type user-type-2_non_member").find_all('b')[1].text
                publish_date.append(date)  
            except:
                publish_date.append('NA')  
    
            bc_type.append(bc)
            review_text.append(body)  
            
            try:
                rate = result.tr.text.strip()
                rating = int(float(rate))
                stars.append(rating)
            except:                
                stars.append('NA')
        try:
            browser.click_link_by_partial_text('Next')

            time.sleep(1)

        except:
            print("Scraping Complete")

# %%
## Number of reviews collected
len(publish_date)
# Out:
# 2400

# %%
bc_df_2 = pd.DataFrame({
    'Birth_Control': bc_type,
    'Star_Rating': stars,
    'Review': review_text,
    'Publish_Date': publish_date
    })

# %%
bc_df_2.head()
# Out:
#                        Birth_Control Star_Rating  \
# 0  medroxyprogesterone/depo-provera-           1
# 1  medroxyprogesterone/depo-provera-           8
# 2  medroxyprogesterone/depo-provera-           1
# 3  medroxyprogesterone/depo-provera-           5
# 4  medroxyprogesterone/depo-provera-           1
#
#                                               Review    Publish_Date
# 0  "I would rate this drug 0 out of 10 if possibl...   April 1, 2019
# 1  "Overall 8/10. I give it 10/10 for effectivene...  March 31, 2019
# 2  "The Deop-provera Brith control shot is the wo...  March 14, 2019
# 3  "The Depo shot has been very effective. I have...  March 10, 2019
# 4  "Depo provera was awful. I gained over 35 poun...   March 7, 2019

# %% [markdown]
# Use VADER sentiment analysis to analyze the review text for each review. How do women feel about their birth control?

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Variables for holding sentiments
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

for review in bc_df_2['Review']:

    # Run Vader Analysis on each review
    results = analyzer.polarity_scores(review)
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]

    # Add each value to the appropriate list
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

# %% [markdown]
# Store it all in a DataFrame, add original data source and birth control type.

# %%
# Store it all in a DataFrame
bc_df_2 = pd.DataFrame({
    'Birth_Control': bc_type,
    'Star_Rating': stars,
    'Review': review_text,
    'Use': 'n/a',
    'Publish_Date': publish_date,
    'Compound': compound_list,
    'Positive': positive_list,
    'Negative': negative_list,
    'Neutral': neutral_list, 
    'Source' : 'Drugs.com'
    })

# %%
# Add type based on the birth control product
for index, row in bc_df_2.iterrows():
    if row['Birth_Control'] == 'medroxyprogesterone/depo-provera-':
        bc_df_2.loc[index,"Method"] = 'Shot'
    elif row['Birth_Control'] == 'levonorgestrel/mirena-':
        bc_df_2.loc[index,"Method"] = 'Hormonal IUD'
    elif row['Birth_Control'] == 'etonogestrel/nexplanon-':
        bc_df_2.loc[index,"Method"] = 'Implant'
    elif row['Birth_Control'] == 'ethinyl-estradiol-norethindrone/':
        bc_df_2.loc[index,"Method"] = 'Progestin Pill'
    elif row['Birth_Control'] == 'ethinyl-estradiol-etonogestrel/nuvaring-':
        bc_df_2.loc[index,"Method"] = 'Ring'
    elif row['Birth_Control'] == 'ethinyl-estradiol-norelgestromin/xulane-':
        bc_df_2.loc[index,"Method"] = 'Patch'
    elif row['Birth_Control'] == 'ethinyl-estradiol-norgestimate/':
        bc_df_2.loc[index,"Method"] = 'Combination Pill'
    elif row['Birth_Control'] == 'copper-topical/':
        bc_df_2.loc[index,"Method"] = 'Non-hormonal IUD'

# %% [markdown]
# Clean up the product names

# %%
bc_df_2['Birth_Control'] = bc_df_2['Birth_Control'].replace({'medroxyprogesterone/depo-provera-': 'Depo-Provera',\
                                                             'levonorgestrel/mirena-':'Mirena',\
                                                             'etonogestrel/nexplanon-': 'Implanon',\
                                                             'ethinyl-estradiol-norethindrone/': 'Norethindrone',\
                                                             'ethinyl-estradiol-etonogestrel/nuvaring-': 'NuvaRing',\
                                                             'ethinyl-estradiol-norelgestromin/xulane-':'Xulane',\
                                                             'ethinyl-estradiol-norgestimate/':'Ortho Tri-Cyclen',\
                                                             'copper-topical/': 'ParaGard'
                                                            })

# %%
bc_df_2.head(100)
# Out:
#    Birth_Control Star_Rating  \
# 0   Depo-Provera           1
# 1   Depo-Provera           8
# 2   Depo-Provera           1
# 3   Depo-Provera           5
# 4   Depo-Provera           1
# 5   Depo-Provera           1
# 6   Depo-Provera           6
# 7   Depo-Provera           5
# 8   Depo-Provera          10
# 9   Depo-Provera           5
# 10  Depo-Provera           6
# 11  Depo-Provera           1
# 12  Depo-Provera           1
# 13  Depo-Provera           1
# 14  Depo-Provera           6
# 15  Depo-Provera           1
# 16  Depo-Provera           4
# 17  Depo-Provera          10
# 18  Depo-Provera           1
# 19  Depo-Provera           1
# 20  Depo-Provera           1
# 21  Depo-Provera           1
# 22  Depo-Provera           2
# 23  Depo-Provera           1
# 24  Depo-Provera           1
# 25  Depo-Provera           1
# 26  Depo-Provera           4
# 27  Depo-Provera           1
# 28  Depo-Provera          NA
# 29  Depo-Provera           8
# ..           ...         ...
# 70  Depo-Provera           5
# 71  Depo-Provera           1
# 72  Depo-Provera           9
# 73  Depo-Provera           1
# 74  Depo-Provera           4
# 75  Depo-Provera          NA
# 76  Depo-Provera          NA
# 77  Depo-Provera           7
# 78  Depo-Provera           1
# 79  Depo-Provera           9
# 80  Depo-Provera           1
# 81  Depo-Provera           1
# 82  Depo-Provera           1
# 83  Depo-Provera          10
# 84  Depo-Provera           3
# 85  Depo-Provera           7
# 86  Depo-Provera           1
# 87  Depo-Provera          NA
# 88  Depo-Provera           2
# 89  Depo-Provera          NA
# 90  Depo-Provera          NA
# 91  Depo-Provera           1
# 92  Depo-Provera          NA
# 93  Depo-Provera           6
# 94  Depo-Provera           1
# 95  Depo-Provera           2
# 96  Depo-Provera          10
# 97  Depo-Provera           3
# 98  Depo-Provera           1
# 99  Depo-Provera           1
#
#                                                Review  Use  \
# 0   "I would rate this drug 0 out of 10 if possibl...  n/a
# 1   "Overall 8/10. I give it 10/10 for effectivene...  n/a
# 2   "The Deop-provera Brith control shot is the wo...  n/a
# 3   "The Depo shot has been very effective. I have...  n/a
# 4   "Depo provera was awful. I gained over 35 poun...  n/a
# 5   "I did the depo shots for about a year and a h...  n/a
# 6   "It did what it was supposed to which is stop ...  n/a
# 7   "I got the shot once and it was TERRIBLE. I ex...  n/a
# 8   "My experience with this shot has been nothing...  n/a
# 9   "I got on the Depo shot January 2016. I gained...  n/a
# 10  "So I got on the depo shot on the summer of 20...  n/a
# 11  "Avoid this form of birth control! It made me ...  n/a
# 12  "The Depo shot is the worse birth control anyo...  n/a
# 13  "Please avoid this medication. I had one injec...  n/a
# 14  "I had 5 shots in total of the Depo. After my ...  n/a
# 15  "Absolutely hate it..I took the birth control ...  n/a
# 16  "The shot does what it supposed to do which is...  n/a
# 17  "I’ve been on the depo shot for 4 years now, n...  n/a
# 18  "I recommend no one ever tries this.  I had my...  n/a
# 19  "I abhor the depo shot! I've been on it for a ...  n/a
# 20  "I had the depo shot three times. The first on...  n/a
# 21  "Don’t use this birth control. I went on birth...  n/a
# 22  "I am due for my second shot this week and wil...  n/a
# 23  "Oh my goodness, I got such bad eczema as a re...  n/a
# 24  "If you’re looking for something to tell you w...  n/a
# 25  "Worst experience of my life, be SCARED of thi...  n/a
# 26  "Horrible experience; I received my 1st shot i...  n/a
# 27  "I have been on the depo for about a year, and...  n/a
# 28  "Best ever after I had my first baby on July 7...  n/a
# 29  "I have been using Depo for about two years no...  n/a
# ..                                                ...  ...
# 70  "I had my first shot of this in October, great...  n/a
# 71  "I had my first shot of this in October. Every...  n/a
# 72  "I’ve been on Depo since 2013 and I love it. A...  n/a
# 73  "I had the Depo shot in 2010 once and it made ...  n/a
# 74  "I took it nearly a year ago. it's useful for ...  n/a
# 75  "I’ve been on the shot for about 2 years now a...  n/a
# 76  "Hey, I’m been on depo Provera off and on. Wel...  n/a
# 77  "My experience, I didn't have a period at all ...  n/a
# 78  "I regret this shot :( I have been in pain for...  n/a
# 79  "So I’ve been on Depo for 5 months, going on 6...  n/a
# 80   Shot
# 81   Shot
# 82   Shot
# 83   Shot
# 84   Shot
# 85   Shot
# 86   Shot
# 87   Shot
# 88   Shot
# 89   Shot
# 90   Shot
# 91   Shot
# 92   Shot
# 93   Shot
# 94   Shot
# 95   Shot
# 96   Shot
# 97   Shot
# 98   Shot
# 99   Shot
#
# [100 rows x 11 columns]

# %%
method_count = pd.DataFrame(bc_df_2['Method'].value_counts())
method_count
# Out:
#                   Method
# Non-hormonal IUD     300
# Patch                300
# Implant              300
# Ring                 300
# Shot                 300
# Progestin Pill       300
# Combination Pill     300
# Hormonal IUD         300

# %%
compound_score = []

for score in bc_df_2['Compound']:
    if score <= 0-.6: 
        compound_score.append('Very Negative')
    elif score <= 0-.2: 
        compound_score.append('Negative')
    elif score <= .2: 
        compound_score.append('Neutral')
    elif score <= .6: 
        compound_score.append('Positive') 
    else:
        compound_score.append('Very Positive')

# %%
bc_df_2['Vader_Scale'] = compound_score

# %%
vader_count = pd.DataFrame(bc_df_2['Vader_Scale'].value_counts())
vader_count
# Out:
#                Vader_Scale
# Very Negative         1112
# Very Positive          581
# Negative               274
# Positive               253
# Neutral                180

# %%
bc_df_2.to_csv('birth_control_site2.csv')

# %% [markdown]
# Add our newly collected data to our existing birth control database on AWS.

# %%
bc_df_2.to_sql(name='birth_control_all', if_exists='append', con=conn, index=False)

# %%
# Check remote database to make sure it migrated correctly
remote_bc_data = pd.read_sql("SELECT * FROM birth_control_all", conn)
print(len(remote_bc_data))
remote_bc_data.head()
# Out:
# 5297
#   Birth_Control  Star_Rating  \
# 0  Depo-Provera            1
# 1  Depo-Provera            5
# 2  Depo-Provera            1
# 3  Depo-Provera            3
# 4  Depo-Provera            1
#
#                                               Review             Use  \
# 0  After 6 years of taking this injection, my wif...  Birth Control
# 1  Have endrometrisos was bleeding from vagina an...  Endometriosis
# 2  I had a miscarriage due to the depo shot. Plea...  Birth Control
# 3  I have been on this for 4/5 years i would reco...  Birth Control
# 4  Ive been on it for 2 months now , I get Horrib...  Birth Control
#
#   Publish_Date  Compound  Positive  Negative  Neutral           Source Method  \
# 0     4/1/2019   -0.5574     0.031     0.075    0.895  Everyday Health   Shot
# 1    3/10/2019   -0.6908     0.051     0.133    0.816  Everyday Health   Shot
# 2     3/8/2019    0.0516     0.144     0.109    0.747  Everyday Health   Shot
# 3    3/6/2019     0.7251     0.212     0.000    0.788  Everyday Health   Shot
# 4     3/5/2019   -0.8772     0.000     0.181    0.819  Everyday Health   Shot
#
#      Vader_Scale
# 0       Negative
# 1  Very Negative
# 2        Neutral
# 3  Very Positive
# 4  Very Negative

# %%
# Check that long string was not truncated during transfer
print(remote_bc_data['Review'][5000])
# Out:
# "The insertion hurt like crazy, but maybe that's all IUD's. My period was much heavier and longer for at least 2 days, on top of my normal 7 day period. I had non-stop spotting in between cycles too. Then, after 1 year and 2 months of occasional intercourse,  with Paragard I got pregnant!
#
# Would not recommend this as a birth control option, unless you really like heavier, longer, and more painful periods and unplanned pregnancies. Use ANYTHING else, trust me. I'm now using a hormonal IUD and pills and haven't gotten pregnant since."
